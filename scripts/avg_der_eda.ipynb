# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/workspaces/ds_project/avg_&_derivative_csv/data5_avg_&_derivative.csv")

# %%
avg = df['avg']
sns.scatterplot(avg, legend="full", color='cyan', s=2)
plt.show()

# %%
der = df['Spectral_Bandwidth']
sns.scatterplot(der, legend="full", color='purple', s=2)
plt.show()

# %%
der = df['first_der']
sns.scatterplot(der, legend="full", color='purple', s=2)
plt.show()
